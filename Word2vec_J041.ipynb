# %% [markdown]
# <a href="https://colab.research.google.com/github/ramdayal51/NaturalLanguageProcessing/blob/master/Word2vec_J041.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import itertools
import pandas as pd
import string
import nltk
from gensim import models
from nltk import word_tokenize
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from itertools import combinations
from itertools import permutations
from string import digits

# %%
data = pd.read_csv("https://raw.githubusercontent.com/zfz/twitter_corpus/master/full-corpus.csv")

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
# ...

# %%
def unique_words(text):
  text = text.translate(text.maketrans('','',string.punctuation))
  text = text.translate(text.maketrans('','',digits))
  tokens = word_tokenize(text)
  result = [word for word in tokens if word not in stop_words]
  return result

# %%
nltk.download('punkt')
data['Tweet_unique_words']= data['TweetText'].apply(unique_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
data['Tweet_unique_words'][1]
# Out:
# ['Apple', 'adding', 'carrier', 'support', 'iPhone', 'S', 'announced']

# %%
word_vec = Word2Vec(data['Tweet_unique_words'], min_count=1)
words = list(word_vec.wv.vocab)
words
# Out:
# ['Now',
#  'Apple',
#  'get',
#  'swype',
#  'iphone',
#  'crack',
#  'Iphone',
#  'adding',
#  'carrier',
#  'support',
#  'iPhone',
#  'S',
#  'announced',
#  'Hilarious',
#  'youtube',
#  'video',
#  'guy',
#  'duet',
#  'apple',
#  'Siri',
#  'Pretty',
#  'much',
#  'sums',
#  'love',
#  'affair',
#  'httptcoExbnQjY',
#  'RIM',
#  'made',
#  'easy',
#  'switch',
#  'See',
#  'ya',
#  'I',
#  'realized',
#  'reason',
#  'got',
#  'twitter',
#  'ios',
#  'thanks',
#  'Im',
#  'current',
#  'Blackberry',
#  'user',
#  'little',
#  'bit',
#  'disappointed',
#  'Should',
#  'move',
#  'Android',
#  'The',
#  'strangest',
#  'things',
#  'said',
#  'far',
#  'SOOO',
#  'glad',
#  'gave',
#  'sense',
#  'humor',
#  'httptcoTWAeUDBp',
#  'via',
#  'HappyPlace',
#  'Great',
#  'close',
#  'personal',
#  'event',
#  'tonight',
#  'Regent',
#  'St',
#  'store',
#  'From',
#  'companies',
#  'experience',
#  'best',
#  'customer',
#  'service',
#  'aside',
#  'zappos',
#  'Just',
# ...

# %%
words[:30]
# Out:
# ['Now',
#  'Apple',
#  'get',
#  'swype',
#  'iphone',
#  'crack',
#  'Iphone',
#  'adding',
#  'carrier',
#  'support',
#  'iPhone',
#  'S',
#  'announced',
#  'Hilarious',
#  'youtube',
#  'video',
#  'guy',
#  'duet',
#  'apple',
#  'Siri',
#  'Pretty',
#  'much',
#  'sums',
#  'love',
#  'affair',
#  'httptcoExbnQjY',
#  'RIM',
#  'made',
#  'easy',
#  'switch']

# %%
similar_words = word_vec.wv.most_similar('apps')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
similar_words
# Out:
# [('Apple', 0.9936639070510864),
#  ('Microsoft', 0.9934406280517578),
#  ('I', 0.9933802485466003),
#  ('apple', 0.9932774305343628),
#  ('twitter', 0.9932475090026855),
#  ('RT', 0.9931958913803101),
#  ('que', 0.9931919574737549),
#  ('de', 0.9930380582809448),
#  ('like', 0.9930309057235718),
#  ('get', 0.9929835200309753)]

# %%
model = Word2Vec(data['Tweet_unique_words'],min_count=1)
model.wv.vocab
# Out:
# {'Now': <gensim.models.keyedvectors.Vocab at 0x7f0295c5ed68>,
#  'Apple': <gensim.models.keyedvectors.Vocab at 0x7f0295c5eda0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f0295c5edd8>,
#  'swype': <gensim.models.keyedvectors.Vocab at 0x7f0295c5ee48>,
#  'iphone': <gensim.models.keyedvectors.Vocab at 0x7f0295c5ea20>,
#  'crack': <gensim.models.keyedvectors.Vocab at 0x7f0295c5e7f0>,
#  'Iphone': <gensim.models.keyedvectors.Vocab at 0x7f0295c5ee80>,
#  'adding': <gensim.models.keyedvectors.Vocab at 0x7f0295c5eeb8>,
#  'carrier': <gensim.models.keyedvectors.Vocab at 0x7f0295c5eef0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f0295c5ef28>,
#  'iPhone': <gensim.models.keyedvectors.Vocab at 0x7f0295c5ef60>,
#  'S': <gensim.models.keyedvectors.Vocab at 0x7f0295c5ef98>,
#  'announced': <gensim.models.keyedvectors.Vocab at 0x7f0295c5efd0>,
#  'Hilarious': <gensim.models.keyedvectors.Vocab at 0x7f0295c5d048>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x7f0295c5d080>,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9a0e94fbd6dd> in <module>()
# ----> 1 for i in range(combos.shape[0]):
#       2     print(combos[0][i],combos[1][i],' : ',model1.wv.similarity(combos[0][i],combos[1][i]))
#
# NameError: name 'combos' is not defined
